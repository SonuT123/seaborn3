# %% [raw]
#                                      Assignment seaborn

# %% [raw]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [raw]
# Seaborn is a data visualization library built on top of Matplotlib in Python.
# It provides a high-level interface for creating attractive and informative statistical graphics.
# Here are five common plots that can be created using Seaborn
#
# 1.Scatter Plot:-
#     >Use: Scatter plots are used to visualize the relationship between two continuous variables.
#     Each data point is represented as a dot, and the x and y coordinates represent the values of the two variables.
#     >Seaborn Function: seaborn.scatterplot()
# 2.Histogram:-
#      >Use: Histograms are used to display the distribution of a single
#          variable by dividing the data into bins and showing the frequency or count of data points in each bin.
#      >Seaborn Function: seaborn.histplot()
#
# 3.Bar Plot:-
#      >Use: Bar plots are used to compare data across different categories or groups.
#        They display rectangular bars with lengths proportional to the values they represent.
#
#     >Seaborn Function: seaborn.barplot()
# 4.Box Plot:-
#      >Use: Box plots (box-and-whisker plots) are used to visualize the distribution of a dataset, showing the median,
#        quartiles, and potential outliers.
#         They are particularly useful for comparing distributions across different groups.
#     >Seaborn Function: seaborn.boxplot()
#
# 5.Heatmap:-
#      Use: Heatmaps are used to display a matrix-like dataset where the values are represented as colors.
#      They are often used to visualize correlation matrices, showing the strength of relationships between variables.
#
#     >Seaborn Function: seaborn.heatmap()

# %% [raw]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
#       "timepoint" and y = "signal" for different events and regions.
#        Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fmri_data = sns.load_dataset("fmri")

plt.figure(figsize=(10, 6))
sns.lineplot(data=fmri_data, x="timepoint", y="signal", hue="event", style="region")

plt.title("Line Plot of FMRI Data")
plt.xlabel("Timepoint")
plt.ylabel("Signal")

plt.legend(title="Event")

plt.show()

# %% [raw]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
#       'pclass', y = 'age' and y = 'fare'.
#      Note: pclass, age, and fare are columns in the titanic dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic_data = sns.load_dataset("titanic")

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.boxplot(data=titanic_data, x='pclass', y='age', ax=axes[0])
axes[0].set_title('Box Plot of Age by Pclass')
axes[0].set_xlabel('Pclass')
axes[0].set_ylabel('Age')

sns.boxplot(data=titanic_data, x='pclass', y='fare', ax=axes[1])
axes[1].set_title('Box Plot of Fare by Pclass')
axes[1].set_xlabel('Pclass')
axes[1].set_ylabel('Fare')

plt.tight_layout()

plt.show()

# %% [raw]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
#        parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

diamonds_data = sns.load_dataset("diamonds")

plt.figure(figsize=(10, 6))
sns.histplot(data=diamonds_data, x='price', hue='cut', multiple="stack")

plt.title("Histogram of Diamond Prices by Cut")
plt.xlabel("Price")
plt.ylabel("Frequency")

plt.legend(title="Cut")

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [raw]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
#        of the iris dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris_data = sns.load_dataset("iris")

sns.pairplot(data=iris_data, hue='species')

plt.title('Pair Plot of Iris Dataset')

plt.legend(title='Species')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [raw]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights_data = sns.load_dataset("flights")

flights_pivot = flights_data.pivot_table(index='month', columns='year', values='passengers')

plt.figure(figsize=(10, 6))
sns.heatmap(data=flights_pivot, cmap='YlGnBu', annot=True, fmt='d')

plt.title('Flights Data Heatmap')
plt.xlabel('Year')
plt.ylabel('Month')

plt.show()
